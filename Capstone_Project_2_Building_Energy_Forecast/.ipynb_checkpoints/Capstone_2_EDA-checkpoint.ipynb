# %% [markdown]
# # Capstone Project #2 Part 2: Exploratory Data Analysis (EDA)

# %% [markdown]
# In this session, we'll explore the data to see if there is obvious pattern and connection between features and our target data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV

from sklearn.metrics import r2_score, mean_squared_log_error, mean_absolute_error
import numpy as np
from tqdm import tqdm
from scipy import stats
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from datetime import datetime
from datetime import timedelta
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar
import pmdarima as pm

# %% [markdown]
# ## 1. Load data

# %%
elec = pd.read_csv('electricity_cleaned.csv',parse_dates=['timestamp']).set_index('timestamp')

# %%
elec.head()
# Out:
#                      building_id  meter_reading
# timestamp
# 2016-05-20 18:00:00            3        248.452
# 2016-05-20 19:00:00            3        336.844
# 2016-05-20 20:00:00            3        358.685
# 2016-05-20 21:00:00            3        377.456
# 2016-05-20 22:00:00            3        373.702

# %%
meta = pd.read_csv('building_metadata.csv')

# %%
weather = pd.read_csv('weather_cleaned.csv',parse_dates=['timestamp']).set_index('timestamp')

# %% [markdown]
# ## 2. Explore the electricity consumption pattern

# %% [markdown]
# For this project we select building no. 1126 as target building

# %%
bldg_id = 1126

# %%
# see some background information for the target building
meta[meta['building_id']==bldg_id]
# Out:
#       site_id  building_id primary_use  square_feet  year_built  floor_count
# 1126       13         1126   Education        72332         NaN          NaN

# %%
df = elec[elec['building_id']==bldg_id].drop(['building_id'],axis=1)

# %%
df.plot(figsize=(20,3))
plt.ylabel('electricity demand (kW)')
# Out:
# Text(0, 0.5, 'electricity demand (kW)')

# %% [markdown]
# The hourly data fluctuates a lot becaust it's at very short intervals. Let's look at monthly average data for a smoother view

# %%
df.resample('M').mean().plot(figsize=(20,3),marker='*')
plt.ylabel('electricity demand (kW)')
# Out:
# Text(0, 0.5, 'electricity demand (kW)')

# %% [markdown]
# Electricity does peak in summer season and bottom in winter season. This is due to increased air conditioning usage as the weather gets warmer.

# %% [markdown]
# Since our goal is to predict daily usage, let's look at daily average electricity demand

# %%
df.resample('D').mean().plot(figsize=(15,3))
plt.ylabel('electricity demand (kW)')
plt.title('Daily Average Electricity Demand')
# Out:
# Text(0.5, 1.0, 'Daily Average Electricity Demand')

# %% [markdown]
# There seems to be some pattern but it's a little hard to see from a whole year scale. Let's zoom in to look at one month

# %%
df.resample('D').mean()['2016-9'].plot(figsize=(15,3),marker='*')
plt.ylabel('electricity demand (kW)')
plt.title('Daily Average Electricity Demand in September')
# Out:
# Text(0.5, 1.0, 'Daily Average Electricity Demand in September')

# %% [markdown]
# When we zoom in, it clearly shows a weekly pattern.

# %% [markdown]
# ## 3. Decomposition on daily average energy usage

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
daily = df.resample('D').mean().meter_reading

# %%
daily['2016-11'].plot(marker='*')
# Out:
# <AxesSubplot:xlabel='timestamp'>

# %%
decomposition = seasonal_decompose(daily)
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

# %%
fig, ax = plt.subplots(3,1,figsize=(15,10))
plt.subplot(311)
plt.plot(daily, label = 'actual')
plt.plot(trend, label = 'trend')
# plt.plot(daily - seasonal, label = 'actual - seasonal')
plt.legend(loc = 'best')

plt.subplot(312)
plt.plot(seasonal, label = 'seasonal')
# plt.plot(daily-trend, label = 'actual - trend')
plt.legend(loc = 'best')

plt.subplot(313)
plt.plot(residual, label = 'Residuals')
plt.legend(loc = 'best')

plt.tight_layout()

# %% [markdown]
# The decomposition process divides the data into three components: trend, seasonality and residual.

# %% [markdown]
# ## 4. Daily electricity usage vs air temperature

# %%
# our target building is in site 13 according to metadata
w = weather[weather['site_id']==13].resample('D')['air_temperature','dew_temperature'].mean()

# %%
# join the weather data and electricity data
daily_w = pd.DataFrame(daily).join(w).dropna()

# %%
# define a function to convert the datetime to weekday/weekend
def ww_convert(x):
    if x <=4:
        return 'Weekday'
    else:
        return 'Weekend'

# %%
daily_w['Day'] = list(map(ww_convert, daily_w.index.dayofweek))

# %%
daily_w.head()
# Out:
#             meter_reading  air_temperature  dew_temperature      Day
# timestamp
# 2016-01-01     179.822913        -6.229167       -10.283333  Weekday
# 2016-01-02     175.222208        -5.837500        -9.945833  Weekend
# 2016-01-03     174.820542        -3.008333        -7.595833  Weekend
# 2016-01-04     194.201375        -7.229167       -10.004167  Weekday
# 2016-01-05     203.131417        -4.637500        -8.208333  Weekday

# %%
fig, ax = plt.subplots(1,2, figsize=(12,5))
sns.scatterplot(data=daily_w,x='air_temperature',y='meter_reading',hue='Day',ax=ax[0])
sns.scatterplot(data=daily_w,x='dew_temperature',y='meter_reading',hue='Day',ax=ax[1])
plt.tight_layout()

# %% [markdown]
# Looks like when air temperature and dew temperature are above a threshold, they start to impact electricity usage. We'll incorporate those features into our model in next session.
